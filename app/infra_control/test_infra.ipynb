# %%
import infra_control as il

myinfra = il.infra()
# Out:
# Neither /dev/ttyACM1 nor /dev/ttyCH340USB1 is present
# COM14

# %%
myinfra.begin()

# %%
myinfra.get_percentage()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myinfra.get_percentage()
#
# AttributeError: 'infra' object has no attribute 'get_percentage'

# %%
myinfra.get_infra()
# Out:
# b'\\x69\\x00\\x01\\x00\\x00\\x03\\x00\\x00'
# 0

# %%
myinfra.config_percentage(80)
# Out:
# ---------------------------------------------------------------------------
# NoResponseError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myinfra.config_percentage(80)
#
# File c:\Users\ACSG\Documents\Python Scripts\acsg_vagogep\backend\infra_control\infra_control.py:63, in infra.config_percentage(self, value)
#      61     self.driver.write_register(10,0)
#      62 else:
# ---> 63     self.driver.write_register(10,value)
#      64 return True
#
# File c:\Users\ACSG\Documents\Python Scripts\acsg_vagogep\backend\.venv\Lib\site-packages\minimalmodbus.py:552, in Instrument.write_register(self, registeraddress, value, number_of_decimals, functioncode, signed)
#     549 _check_bool(signed, description="signed")
#     550 _check_numerical(value, description="input value")
# --> 552 self._generic_command(
#     553     functioncode,
#     554     registeraddress,
#     555     value,
#     556     number_of_decimals=number_of_decimals,
#     557     number_of_registers=1,
#     558     signed=signed,
#     559     payloadformat=_Payloadformat.REGISTER,
#     560 )
#
# File c:\Users\ACSG\Documents\Python Scripts\acsg_vagogep\backend\.venv\Lib\site-packages\minimalmodbus.py:1276, in Instrument._generic_command(self, functioncode, registeraddress, value, number_of_decimals, number_of_registers, number_of_bits, signed, byteorder, payloadformat)
#    1263 payload_to_slave = _create_payload(
#    1264     functioncode,
#    1265     registeraddress,
#    (...)
#    1272     payloadformat,
#    1273 )
#    1275 # Communicate with instrument
# -> 1276 payload_from_slave = self._perform_command(functioncode, payload_to_slave)
#    1278 # There is no response for broadcasts
#    1279 if self.address == _SLAVEADDRESS_BROADCAST:
#
# File c:\Users\ACSG\Documents\Python Scripts\acsg_vagogep\backend\.venv\Lib\site-packages\minimalmodbus.py:1353, in Instrument._perform_command(self, functioncode, payload_to_slave)
#    1346             self._print_debug(
#    1347                 template.format(
#    1348                     self.mode, number_of_bytes_to_read, request_bytes
#    1349                 )
#    1350             )
#    1352 # Communicate
# -> 1353 response_bytes = self._communicate(request_bytes, number_of_bytes_to_read)
#    1355 if number_of_bytes_to_read == 0:
#    1356     return b""
#
# File c:\Users\ACSG\Documents\Python Scripts\acsg_vagogep\backend\.venv\Lib\site-packages\minimalmodbus.py:1521, in Instrument._communicate(self, request, number_of_bytes_to_read)
#    1518     self._print_debug(text)
#    1520 if not answer and number_of_bytes_to_read > 0:
# -> 1521     raise NoResponseError("No communication with the instrument (no answer)")
#    1523 if number_of_bytes_to_read == 0:
#    1524     self._print_debug(
#    1525         "Broadcast delay: Sleeping for {} s".format(_BROADCAST_DELAY)
#    1526     )
#
# NoResponseError: No communication with the instrument (no answer)

# %%
myinfra.turn_infra(False)
# Out:
# 0
